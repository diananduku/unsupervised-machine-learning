# %%
##importing the dataset
import pandas as pd
data=pd.read_csv(r"C:\Users\USER\OneDrive\Data Science books\datasets\archive (16)\CC GENERAL.csv")
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
##data exploration
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
## 2 columns have null values- credit_limit and minimum_payments

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2568\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# ...

# %%
##there is no strong correlation between minimum payments and another variable
##therefore will fill missing values with the mean

# %%
##calculating mean for minimum_payments
mean_value=data['MINIMUM_PAYMENTS'].mean()
mean_value
# Out:
# 864.2065423050828

# %%
##filling in the missing values with the mean
data['MINIMUM_PAYMENTS'].fillna(mean_value, inplace=True)

# %%
##filling in missing value in purchases_trx using forward fill
data['CREDIT_LIMIT'].fillna(method='ffill', inplace=True)

# %%
data.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
##summary statistics
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
##dropping the customer_id column
df=data.drop('CUST_ID',axis=1)
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
##visualization of individual features
import matplotlib.pyplot as plt
import seaborn as sns
fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(12, 12))
variables = df.columns
axes = axes.flatten()
# Loop through each variable and create subplots
for i, variable in enumerate(variables):
    ax = axes[i]
    sns.histplot(df[variable], ax=ax, kde=True, bins=20)
    ax.set_title(f'Distribution of {variable}')
    ax.set_xlabel(variable)
    ax.set_ylabel('Frequency')
    
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
    
plt.subplots_adjust(wspace=0.4, hspace=0.8)

# %%
##since the data is higly varied, normalize it
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
normalized_data=scaler.fit_transform(df)
# Out:
# array([[2.14779454e-03, 8.18182000e-01, 1.94536779e-03, ...,
#         1.82564563e-03, 0.00000000e+00, 1.00000000e+00],
#        [1.68169097e-01, 9.09091000e-01, 0.00000000e+00, ...,
#         1.40344791e-02, 2.22222000e-01, 1.00000000e+00],
#        [1.31026136e-01, 1.00000000e+00, 1.57662475e-02, ...,
#         8.20961806e-03, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [1.22871936e-03, 8.33333000e-01, 2.94456089e-03, ...,
#         1.07843629e-03, 2.50000000e-01, 0.00000000e+00],
#        [7.06688341e-04, 8.33333000e-01, 0.00000000e+00, ...,
#         7.29475795e-04, 2.50000000e-01, 0.00000000e+00],
#        [1.95717777e-02, 6.66667000e-01, 2.22932216e-02, ...,
#         1.15527021e-03, 0.00000000e+00, 0.00000000e+00]])

# %%
#column_names=data.columns
data1=pd.DataFrame(normalized_data,columns=df.columns)
data1
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     0.002148           0.818182   0.001945          0.000000
# 1     0.168169           0.909091   0.000000          0.000000
# 2     0.131026           1.000000   0.015766          0.018968
# 3     0.087521           0.636364   0.030567          0.036775
# 4     0.042940           1.000000   0.000326          0.000393
# ...        ...                ...        ...               ...
# 8945  0.001496           1.000000   0.005936          0.000000
# 8946  0.001007           1.000000   0.006118          0.000000
# 8947  0.001229           0.833333   0.002945          0.000000
# 8948  0.000707           0.833333   0.000000          0.000000
# 8949  0.019572           0.666667   0.022293          0.026821
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   0.004240      0.000000             0.166667
# 1                   0.000000      0.136685             0.000000
# ...

# %%
##performing k-means clustering
from sklearn.cluster import KMeans
x=normalized_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
##elbow method to calculate the optimal number of clusters
sse = []  # Initialize the list to store SSE values
k_range = range(1, 11)  # Define the range of K values

for k in k_range:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=1)
    kmeans.fit(x)
    sse.append(kmeans.inertia_)

plt.figure(figsize=(8, 6))
plt.plot(k_range, sse, marker='o', linestyle='-', color='b')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
##ideal number of clusters is 2

# %%
kmeans = KMeans(n_clusters=2,init='k-means++')
labels=data1['cluster_label'] = kmeans.fit_predict(x)
labels
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 0, ..., 0, 1, 1])

# %%
labels.shape
# Out:
# (8950,)

# %%
##visualizing the clusters for balance against purchases
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data1, x='BALANCE', y='PURCHASES', hue='cluster_label', palette='viridis', s=100)
plt.title('K-means Clustering of Balance against Purchases')
plt.xlabel('BALANCE')
plt.ylabel('PURCHASES')
plt.legend(title='Cluster_label')
plt.show()

# %%
##visualizing the clusters for payments against cash_sdvance_trx
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data1, x='PAYMENTS', y='CASH_ADVANCE_TRX', hue='cluster_label', palette='viridis', s=100)
plt.title('K-means Clustering of Payments against Cash Advance')
plt.xlabel('PAYMENTS')
plt.ylabel('CASH_ADVANCE_TRX')
plt.legend(title='Cluster_label')
plt.show()

# %%
##since the clusters are overlapping, use PCA to make principal components
from sklearn.decomposition import PCA

# %%
##scree plot to determine optimal number of principal components
pca = PCA()
pca.fit(df)
explained_variances = pca.explained_variance_ratio_

# Create a scree plot
plt.figure(figsize=(8, 6))
plt.bar(range(1, len(explained_variances) + 1), explained_variances, alpha=0.7, align='center')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.show()

# %%
##number of components is 2 ; following the elbow point

# %%
numComponents=2
pca=PCA(n_components=numComponents)
principal_components=pca.fit_transform(data1)
principal_components
# Out:
# array([[-0.65957664, -0.098626  ],
#        [-0.75756551, -0.02085653],
#        [ 0.58866335,  0.91845287],
#        ...,
#        [ 0.63599777, -0.42445906],
#        [-0.7818528 , -0.20602767],
#        [-0.36022545,  0.40294755]])

# %%
##k-means clustering for the principal components
cluster_labels = kmeans.fit_predict(principal_components)
cluster_labels
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 1, ..., 1, 0, 0])

# %%
# Visualize the results
plt.scatter(principal_components[:, 0], principal_components[:, 1], c=cluster_labels)
plt.title('K-means Clustering with 2 Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
##silhouette score to determine quality of clustering
from sklearn.metrics import silhouette_score
silhouette_score = silhouette_score(principal_components, cluster_labels)
silhouette_score
# Out:
# 0.7244123680066668

# %%
##since silhouette test is closer to 1, this indicated batter quality of clustering

# %%
#davies_bouldin_score
from sklearn.metrics import davies_bouldin_score
db_index = davies_bouldin_score(principal_components, cluster_labels)
db_index
# Out:
# 0.43124702219360345

# %%
##the score is lower indicating better clustering

# %%
##appending cluster labels to the initial raw data
data['Cluster_balels']=cluster_labels
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...
